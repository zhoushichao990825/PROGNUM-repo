# %% [markdown]
# $$E=hc/\lambda$$

# %% [markdown]
# $$F=G\frac{m_1m_2}{r^2}$$

# %% [markdown]
# $$sin(2x)=2sin(x)cos(x)=\frac{2tan(x)}{1+tan(x)^2}$$

# %%
from math import *

# %%
alpha_d = 30
alpha_r = radians(alpha_d)
print(alpha_r)
# Out:
# 0.5235987755982988

# %% [markdown]
# $$\displaystyle\sum_{k=0}^{\infty} \frac{1}{4k^2 -1} = \frac{1}{2}$$
# $$\int_0^\pi\mathrm{e}^{ix}\,\mathrm{d}x$$

# %%
from math import exp, log
exp(log(50))
# Out:
# 49.99999999999999

# %%
from math import factorial
factorial (9)
# Out:
# 362880

# %%
from math import atan2 ,tan
x=2
y=3
phi=atan2(x,y)
tan(phi)==y/x
# Out:
# False

# %%
from math import atan2, degrees, pi

x=float(input("enter the x coordinate"))
y=float(input("enter the y coordinate"))

angle_r= atan2(y,x)
n= degrees(angle_r)

if 0 <= n < 90:
    quadrant= "The First Quadrant"
elif 90 <= n < 180 :
    quadrant= "The Second Quadrant"
elif 180 <= n < 270 :
    quadrant= "The Third Quadrant"
else:
    quadrant= "The Fourth Quadrant"

print(f"Angle: n = {n} --{quadrant}")
# Out:
# enter the x coordinate10
# enter the y coordinate-10
# Angle: n = -45.0 --The Fourth Quadrant

# %%
x = [1.36,1.46,1.41,2.12,0.42,0.98,0.45,1.97,-0.24,2.18]
x.append(0.51)
x.remove(2.12)
value_at_6 = x[6]
print("The value at index 6 is:",value_at_6)
index_of_value = x.index(1.46)
print("The index number of value 1.46 is:",index_of_value)
s = slice(2,8,2)
result = x[s]
print("sliced list", result)
print("Sum of slice", sum(result))
# Out:
# The value at index 6 is: 1.97
# The index number of value 1.46 is: 1
# sliced list [1.41, 0.98, 1.97]
# Sum of slice 4.359999999999999

# %%
night1 = [1,3,2,4,0,3,7,5,2,9,2,4,3]
night2 = [0,0,2,4,2,4,3,2,1,1,1,2,0]
set1 = set(night1)
set2 = set(night2)
common_values_set = set1.intersection(set2)
intersection_list = list(common_values_set)
print("intersection_list:",intersection_list)
is_5_in_intersection = 5 in intersection_list
print("Is 5 in the intersectionlist",is_5_in_intersection)
is_5_in_night1_set = 5 in set1
print("Is 5 in night1",is_5_in_night1_set)
# Out:
# intersection_list: [0, 1, 2, 3, 4]
# Is 5 in the intersectionlist False
# Is 5 in night1 True

# %%
import numpy as np
mu, sigma = 0, 1.4    # mean and standard deviation
s = numpy.random.normal(mu, sigma, 100000)
calculated_sigma = np.std(s)
print("calculated standard deviation is:",calculated_sigma)
# Out:
# calculated standard deviation is: 1.3951256268644117

# %%
a = 1
b = 2
for i in range (3,101):
    next_term = a+b
    a = b
    b = next_term
print(f"the 100th term is:{b}")
# Out:
# the 100th term is:573147844013817084101

# %% [markdown]
# ![github.png](attachment:github.png)
