# %%
import sys
print(sys.version)
# Out:
# 3.10.9 (main, Mar  1 2023, 18:23:06) [GCC 11.2.0]

# %% [markdown]
# Answers For Week 1
#
# * Name:Shichao Zhou
# * Username: szhou
# * Student s-number: S6463002
# * Group: AS3

# %%
x=22/7

# %% [markdown]
# $$y=\frac{sin(x)}{x}$$

# %%
pi=22/7 # Processed on Jupyter Hub

# %%
import math
from scipy.constants import G

MassMoon=7.342e22
MassEarth=5.9722e24
Distance=385006600

Force=(G*MassMoon*MassEarth/(Distance**2))

print("Force:",Force)
# Out:
# Force: 1.9743225140988484e+20

# %%
import math
from scipy.constants import c,h
frequency=2.42e28
Energy=(h*frequency)
print("Energy",Energy)
# Out:
# Energy 1.6035089763e-05

# %%
a=6
a*=5
print(a)
# Out:
# 30

# %%
from scipy.constants import pi, G
P=1
a=1
combinedmass=(4*pi**2*a**3)/(G*P**2)
print(combinedmass)
# Out:
# 591498997712.9802

# %% [markdown]
# ![Screenshot%20Prognum.png](attachment:Screenshot%20Prognum.png)

# %%
Question 1.11 the . in tree -d . represenst the current directory.
